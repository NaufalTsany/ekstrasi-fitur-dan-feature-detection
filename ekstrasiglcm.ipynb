# %%
import matplotlib.pyplot as plt
from skimage.feature import graycomatrix, graycoprops
import cv2
PATCH_SIZE = 21

# %%
image = cv2.cvtColor(cv2.imread('images/wp.jpg'),cv2.COLOR_BGR2RGB)
grass_locations = [(280, 454), (342, 223), (444, 192), (455, 455)]
grass_patches = []
for loc in grass_locations:
    grass_patches.append(image[loc[0]:loc[0] + PATCH_SIZE,
                               loc[1]:loc[1] + PATCH_SIZE])
sky_locations = [(38, 34), (139, 28), (37, 437), (145, 379)]
sky_patches = []
for loc in sky_locations:
    sky_patches.append(image[loc[0]:loc[0] + PATCH_SIZE,
                             loc[1]:loc[1] + PATCH_SIZE])

# %%
xs = []
ys = []
for patch in (grass_patches + sky_patches):
    glcm = graycomatrix(patch, distances=[5], angles=[0], levels=256,
                        symmetric=True, normed=True)
    xs.append(graycoprops(glcm, 'dissimilarity')[0, 0])
    ys.append(graycoprops(glcm, 'correlation')[0, 0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 ys = []
#       3 for patch in (grass_patches + sky_patches):
# ----> 4     glcm = graycomatrix(patch, distances=[5], angles=[0], levels=256,
#       5                         symmetric=True, normed=True)
#       6     xs.append(graycoprops(glcm, 'dissimilarity')[0, 0])
#       7     ys.append(graycoprops(glcm, 'correlation')[0, 0])
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\feature\texture.py:109, in graycomatrix(image, distances, angles, levels, symmetric, normed)
#      14 def graycomatrix(image, distances, angles, levels=None, symmetric=False,
#      15                  normed=False):
#      16     """Calculate the gray-level co-occurrence matrix.
#      17
#      18     A gray level co-occurrence matrix is a histogram of co-occurring
#    (...)
#     107
#     108     """
# --> 109     check_nD(image, 2)
#     110     check_nD(distances, 1, 'distances')
#     111     check_nD(angles, 1, 'angles')
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\skimage\_shared\utils.py:590, in check_nD(array, ndim, arg_name)
#     588     raise ValueError(msg_empty_array % (arg_name))
#     589 if array.ndim not in ndim:
# --> 590     raise ValueError(
#     591         msg_incorrect_dim % (arg_name, '-or-'.join([str(n) for n in ndim]))
#     592     )
#
# ValueError: The parameter `image` must be a 2-dimensional array

# %%
fig = plt.figure(figsize=(8, 8))
# tampilkan original image dengan lokasi patches
ax = fig.add_subplot(3, 2, 1)
ax.imshow(image, cmap=plt.cm.gray,
          vmin=0, vmax=255)
for (y, x) in grass_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'gs')
for (y, x) in sky_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'bs')
ax.set_xlabel('Original Image')
ax.set_xticks([])
ax.set_yticks([])
ax.axis('image')
# Out:
# (-0.5, 699.5, 488.8, -0.5)

# %%
ax = fig.add_subplot(3, 2, 2)
ax.plot(xs[:len(grass_patches)], ys[:len(grass_patches)], 'go',
label='Grass')
ax.plot(xs[len(grass_patches):], ys[len(grass_patches):], 'bo',
label='Sky')
ax.set_xlabel('GLCM Dissimilarity')
ax.set_ylabel('GLCM Correlation')
ax.legend()

# %%
# display
for i, patch in enumerate(grass_patches):
    ax = fig.add_subplot(3, len(grass_patches), len(grass_patches)*1 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray,
              vmin=0, vmax=255)
    ax.set_xlabel('Grass %d' % (i + 1))
for i, patch in enumerate(sky_patches):
    ax = fig.add_subplot(3, len(sky_patches), len(sky_patches)*2 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray,
              vmin=0, vmax=255)
    ax.set_xlabel('Sky %d' % (i + 1))

# display
fig.suptitle('Grey level co-occurrence matrix features', fontsize=14, y=1.05)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 4
#       2 for i, patch in enumerate(grass_patches):
#       3     ax = fig.add_subplot(3, len(grass_patches), len(grass_patches)*1 + i + 1)
# ----> 4     ax.imshow(patch, cmap=plt.cm.gray,
#       5               vmin=0, vmax=255)
#       6     ax.set_xlabel('Grass %d' % (i + 1))
#       7 for i, patch in enumerate(sky_patches):
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:1459, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1456 @functools.wraps(func)
#    1457 def inner(ax, *args, data=None, **kwargs):
#    1458     if data is None:
# -> 1459         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1461     bound = new_sig.bind(ax, *args, **kwargs)
#    1462     auto_label = (bound.arguments.get(label_namer)
#    1463                   or bound.kwargs.get(label_namer))
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\axes\_axes.py:5665, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5657 self.set_aspect(aspect)
#    5658 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5659                       interpolation=interpolation, origin=origin,
#    5660                       extent=extent, filternorm=filternorm,
#    5661                       filterrad=filterrad, resample=resample,
#    5662                       interpolation_stage=interpolation_stage,
#    5663                       **kwargs)
# -> 5665 im.set_data(X)
#    5666 im.set_alpha(alpha)
#    5667 if im.get_clip_path() is None:
#    5668     # image does not already have clipping set, clip to axes patch
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\image.py:719, in _ImageBase.set_data(self, A)
#     713 if self._A.ndim == 3:
#     714     # If the input data has values outside the valid range (after
#     715     # normalisation), we issue a warning and then clip X to the bounds
#     716     # - otherwise casting wraps extreme values, hiding outliers and
#     717     # making reliable interpretation impossible.
#     718     high = 255 if np.issubdtype(self._A.dtype, np.integer) else 1
# --> 719     if self._A.min() < 0 or high < self._A.max():
#     720         _log.warning(
#     721             'Clipping input data to the valid range for imshow with '
#     722             'RGB data ([0..1] for floats or [0..255] for integers).'
#     723         )
#     724         self._A = np.clip(self._A, 0, high)
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\ma\core.py:5816, in MaskedArray.min(self, axis, out, fill_value, keepdims)
#    5814 # No explicit output
#    5815 if out is None:
# -> 5816     result = self.filled(fill_value).min(
#    5817         axis=axis, out=out, **kwargs).view(type(self))
#    5818     if result.ndim:
#    5819         # Set the mask
#    5820         result.__setmask__(newmask)
#
# File c:\Users\Risya Fahrisa\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:45, in _amin(a, axis, out, keepdims, initial, where)
#      43 def _amin(a, axis=None, out=None, keepdims=False,
#      44           initial=_NoValue, where=True):
# ---> 45     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# ValueError: zero-size array to reduction operation minimum which has no identity
